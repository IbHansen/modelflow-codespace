# %% [markdown]
# # ModelFlow in GitHub Codespaces
#
# This notebook opens automatically when the codespace starts.
# Run the cells with **Shift+Enter**, or all of them with **Run → Run All Cells**.

# %%
from modelclass import model

model.widescreen()
model.scroll_off()

# %% [markdown]
# A tiny model, to check that ModelFlow works:

# %%
mtest = model('FRML <> Y = C + I $ FRML <> C = 0.8*Y $')
sorted(mtest.endogene)
